# %%
import pandas as pd

df = pd.read_csv("data/raw/complaints.csv")

# %%
print(df["Product"].value_counts())
# Out:
# ----------------------------------------------------
# NameError          Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 print(df["Product"].value_counts())
#
# NameError: name 'df' is not defined
